# %% [markdown]
# Checking Model Performance

# %%
from image.images import getCategoryImageData,get_general_imageData
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
def plotResult(predict,x, y):
    fig, axes = plt.subplots(nrows=4, ncols=2, figsize=(8, 8))
    for i, ax in enumerate(axes.flat):
        if i < len(x):
            # Show the image
            ax.imshow(x[i], cmap='gray')
            ax.axis('off')  # Turn off the axis
            
            # Set the title with predicted and actual classes
            ax.set_title(f"Predicted Class {0 if predict[i]<0.5 else 1}, Actual Class {y[i]}")

# %%
ndata = getCategoryImageData("val", "NORMAL")
x_n = np.array([dt[0]/255 for dt in ndata])
y_n = np.array([dt[1] for dt in ndata])


loaded_model = tf.keras.models.load_model(f"../trainedModels/model1/model40.h5")
predict_n = loaded_model.predict(x_n)
print(predict_n)

plotResult(predict_n, x_n, y_n)
# Out:
# 1/1 [==============================] - 5s 5s/step
# [[0.22501391]
#  [0.49685302]
#  [0.5090818 ]
#  [0.3090169 ]
#  [0.75559866]
#  [0.49373263]
#  [0.03081767]
#  [0.01611541]]

# %%
pdata = getCategoryImageData("val", "PNEUMONIA")
x_p = np.array([dt[0]/255 for dt in pdata])
y_p = np.array([dt[1] for dt in pdata])
predict_p = loaded_model.predict(x_p)
print(predict_p)
plotResult(predict_p, x_p, y_p)
# Out:
# 1/1 [==============================] - 0s 14ms/step
# [[0.98118985]
#  [0.85283226]
#  [0.96873236]
#  [0.97437257]
#  [0.882807  ]
#  [0.9971289 ]
#  [0.9442863 ]
#  [0.8924393 ]]

# %%
# Display Confusion matrix 
def plotConfusionMatrix(model, x_test, y_test, threshold=0.5):
    
    
    predictions = model.predict(x_test)
    predicted_classes = (predictions > threshold).astype(int)  

    # Computing confusion matrix
    cm = confusion_matrix(y_test, predicted_classes)

    # displaying confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Normal", "Pneumonia"])
    disp.plot(cmap=plt.cm.Blues, values_format="d")
    plt.title("Confusion Matrix")
    plt.show()

val_data= get_general_imageData("test")
x_val = np.array([dt[0]/255 for dt in val_data])
y_val = np.array([dt[1] for dt in val_data])
plotConfusionMatrix(loaded_model, x_val, y_val, 0.5)
# Out:
# 1/1 [==============================] - 0s 32ms/step
